# %%
%gnuplot inline pngcairo font "Arial,10" size 950,600
set boxwidth 0.5 absolute
set yrange [0:300]
set xrange [0.5:45.5]
set style fill solid 0.5 noborder 
set style data histogram
set xtics 1
set ytics 20
set ylabel "FRECUENCIA"
set xlabel "BALOTAS (1-45)"
set boxwidth 0.5 relative 
plot 'Frecuencia.txt' u 1:2 smooth frequency with boxes t 'Estadistica de numeros'
# Out:
# set boxwidth 0.5 absolute
# set yrange [0:300]
# set xrange [0.5:45.5]
# set style fill solid 0.5 noborder
# set style data histogram
# set xtics 1
# set ytics 20
# set ylabel "FRECUENCIA"
# set xlabel "BALOTAS (1-45)"
# set boxwidth 0.5 relative
# set output '/tmp/gnuplot-inline-1478068152.06.772678733798.png'
# plot 'Frecuencia.txt' u 1:2 smooth frequency with boxes t 'Estadistica de numeros'
#
#
# gnuplot> gnuplot> unset output
